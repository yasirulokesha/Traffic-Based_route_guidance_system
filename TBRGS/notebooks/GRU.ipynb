# %% [markdown]
# # Traffic-based Route Guidance Solution
#
# ## Import the Dependancies and Library

# %%
import random
import os

import pandas as pd
import numpy as np
import joblib

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras import Input

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.models import load_model

import matplotlib.pyplot as plt

SEED = 42
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# %% [markdown]
# ## Data Preprocessing & Analyzing
#
# 1. Load the VicRoads Boroondara dataset (.csv)
#
# 2. Clean and preprocess:
#     * Convert timestamps
#
#     * Handle missing values
#
#     * Normalize/scale traffic flow values
#
# 3. Reshape for time-series forecasting (e.g., sequences of past 1-2 hours to predict next 15-min slot)
#
# ### Import the Dataset for analyze

# %%
main_dataset = pd.read_csv('https://raw.githubusercontent.com/yasirulokesha/IntroToAI-Assignment-2B/refs/heads/main/TBRGS/data/raw/Scats%20Data%20October%202006.csv', skiprows=1)

# %% [markdown]
# ### Cluster and Make the Train and Test the Datasets

# %%
# Create time mapping for V00–V95 (15-minute intervals)
time_labels = [f"{h:02}:{m:02}:00" for h in range(24) for m in range(0, 60, 15)]
v_columns = [f"V{str(i).zfill(2)}" for i in range(96)]
time_map = dict(zip(v_columns, time_labels))

# Melt the V columns into long format
df_melted = main_dataset.melt(
    id_vars=["SCATS Number", "Location", "Date"],
    value_vars=v_columns,
    var_name="time_code",
    value_name="volume"
)

# Map time codes to actual time strings
df_melted['time_str'] = df_melted['time_code'].map(time_map)

# Combine Date and Time into a full timestamp
df_melted['timestamp'] = pd.to_datetime(df_melted['Date'] + ' ' + df_melted['time_str'], dayfirst=True)

# Rename columns for clarity
df_melted = df_melted.rename(columns={
    "SCATS Number": "site_id",
    "Location": "location"
})

# Select and reorder important columns
df_traffic = df_melted[["site_id", "location", "timestamp", "volume"]]

# 🔁 AGGREGATE: Sum volume over all directions at each site per timestamp
final_dataset = df_melted.groupby(['site_id', 'timestamp'])['volume'].sum().reset_index()

sites = final_dataset['site_id'].unique()

final_dataset.to_csv('../data/processed/processed_dataset.csv', index=False)

# %% [markdown]
# ### Data processing for ML
#
# #### Create Time Series Sequences for Training and Testing purposes

# %%
# Define a function for creating sequences
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# %% [markdown]
# ### Make the unique sequences for different sites

# %%
def generating_sequences(data_set):
    x, y = create_sequences(data_set, 96)
    x = x.reshape(-1, 96, 1)
    return x,y

# %% [markdown]
# ### Drop Outliers

# %%
# Replace outliers using IQR
def replace_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)  # First quartile (25th percentile)
    Q3 = df[column].quantile(0.75)  # Third quartile (75th percentile)
    IQR = Q3 - Q1  # Interquartile range

    # Define bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Replace outliers with the median
    median = df[column].median()
    df[column] = df[column].apply(lambda x: median if x < lower_bound or x > upper_bound else x)
    return df

# %% [markdown]
# ## - Generating the models and save for predictions

# %%
for id in sites:
    print(id)
    site_data = final_dataset[final_dataset['site_id'] == id].sort_values("timestamp")
    
    replace_outliers_iqr(site_data, 'volume')
    
    # Scale Data
    scaler = MinMaxScaler()

    site_data['volume'] = scaler.fit_transform(site_data[['volume']])
    
    site_data = np.array(site_data['volume'])
    
    x, y = generating_sequences(site_data)
    
    # Split into training and testing
    split = int(len(x) * 0.8)
    X_train, X_test = x[:split], x[split:]
    Y_train, Y_test = y[:split], y[split:]
    
    # Define the LSTM model
    model = Sequential([
        Input(shape=(96, 1)),
        GRU(64, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    
    # Train the model
    model.fit(
        X_train, Y_train,
        validation_data=(X_test, Y_test),
        epochs=40,
        batch_size=96
        # callbacks = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    )
    
    # Save the model
    model.save(f"../src/models/GRU_model/models/gru_model_site_{id}.keras")  # New format

    joblib.dump(scaler, f"../src/models/GRU_model/scalers/scaler_site_{id}.save")

    print(f"\n✅ Model and scaler saved for site {id}.")

# %% [markdown]
# ## Test Predictions using seved models and scalers

# %%
# Replace outliers using IQR
replace_outliers_iqr(final_dataset, 'volume')

for id in sites:
    # Load the model and scaler
    model = load_model(f"../src/models/GRU_model/models/gru_model_site_{id}.keras")
    scaler = joblib.load(f"../src/models/GRU_model/scalers/scaler_site_{id}.save")
    print(f"\n🚦 Loading model and scaler for site {id}...")
    
    # Filter data for this site
    site_data = final_dataset[final_dataset['site_id'] == id].sort_values("timestamp")
    
    site_data['volume'] = scaler.transform(site_data[['volume']])
    
    # Predictions for the next time step
    last_site_data = np.array(site_data['volume'][-96:]).reshape(-1, 96, 1)
   
    # Make predictions on the test set
    last_test_site_data = np.array(site_data['volume'][:97])
    
    testX, testY = generating_sequences(last_test_site_data)
    
    testX = testX.reshape(-1, 96, 1)
    
    # Make predictions on the test set
    y_pred = model.predict(testX)

    # Reverse scaling if necessary
    y_test_actual = scaler.inverse_transform(testY.reshape(-1, 1))
    y_pred_actual = scaler.inverse_transform(y_pred)

    smape = 100 * abs(y_pred_actual - y_test_actual) / ((abs(y_pred_actual) + abs(y_test_actual)) / 2)
    accuracy = 100 - smape
    accuracy = np.mean(accuracy)
    print(f"Accuracy: {accuracy:.2f}%")
    
    pred_scaled = model.predict(last_site_data)
    pred_volume = scaler.inverse_transform(pred_scaled)[0][0]

    # print(f"Predicted volume for the next time step: {pred_volume:.2f}")
    # print(pred_scaled)
    print(pred_volume)
# Out:
# 🚦 Loading model and scaler for site 970...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Accuracy: 88.95%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 111.47042
#
# 🚦 Loading model and scaler for site 2000...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 93.60%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 158.48059
#
# 🚦 Loading model and scaler for site 2200...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Accuracy: 81.26%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 37.573788
#
# 🚦 Loading model and scaler for site 2820...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Accuracy: 97.25%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 44.049896
#
# 🚦 Loading model and scaler for site 2825...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 71.31%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 31.54718
#
# 🚦 Loading model and scaler for site 2827...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy: 70.23%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 113.131615
#
# 🚦 Loading model and scaler for site 2846...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Accuracy: 80.43%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 36.326683
#
# 🚦 Loading model and scaler for site 3001...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy: 34.70%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 171.09277
#
# 🚦 Loading model and scaler for site 3002...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Accuracy: 98.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 126.23589
#
# 🚦 Loading model and scaler for site 3120...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Accuracy: 89.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 173.37343
#
# 🚦 Loading model and scaler for site 3122...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy: 70.91%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 40.35046
#
# 🚦 Loading model and scaler for site 3126...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Accuracy: 75.07%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 57.994152
#
# 🚦 Loading model and scaler for site 3127...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Accuracy: 65.27%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 52.347916
#
# 🚦 Loading model and scaler for site 3180...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Accuracy: 39.98%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 23.674692
#
# 🚦 Loading model and scaler for site 3662...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 62.72%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 141.16125
#
# 🚦 Loading model and scaler for site 3682...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 89.56%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 55.24356
#
# 🚦 Loading model and scaler for site 3685...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy: 91.59%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 44.350204
#
# 🚦 Loading model and scaler for site 3804...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Accuracy: 25.52%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 46.622974
#
# 🚦 Loading model and scaler for site 3812...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy: 54.52%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 60.278652
#
# 🚦 Loading model and scaler for site 4030...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Accuracy: 89.72%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 95.038536
#
# 🚦 Loading model and scaler for site 4032...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Accuracy: 72.77%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 77.54903
#
# 🚦 Loading model and scaler for site 4034...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Accuracy: 93.48%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 66.1916
#
# 🚦 Loading model and scaler for site 4035...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy: 98.35%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 88.74734
#
# 🚦 Loading model and scaler for site 4040...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Accuracy: 64.74%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 137.0879
#
# 🚦 Loading model and scaler for site 4043...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Accuracy: 99.58%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 141.6134
#
# 🚦 Loading model and scaler for site 4051...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy: 60.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 29.948595
#
# 🚦 Loading model and scaler for site 4057...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Accuracy: 52.11%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 22.056904
#
# 🚦 Loading model and scaler for site 4063...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy: 97.50%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 41.81234
#
# 🚦 Loading model and scaler for site 4262...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 97.75%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 42.320534
#
# 🚦 Loading model and scaler for site 4263...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 79.22%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 92.005875
#
# 🚦 Loading model and scaler for site 4264...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 92.17%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 85.531204
#
# 🚦 Loading model and scaler for site 4266...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Accuracy: 90.89%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 89.07493
#
# 🚦 Loading model and scaler for site 4270...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 88.85%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 92.24391
#
# 🚦 Loading model and scaler for site 4272...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 85.91%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 55.26778
#
# 🚦 Loading model and scaler for site 4273...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Accuracy: 51.97%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 18.544916
#
# 🚦 Loading model and scaler for site 4321...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Accuracy: 44.66%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 61.19494
#
# 🚦 Loading model and scaler for site 4324...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 96.86%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 41.424263
#
# 🚦 Loading model and scaler for site 4335...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Accuracy: 2.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 50.161137
#
# 🚦 Loading model and scaler for site 4812...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Accuracy: 62.79%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 63.323963
#
# 🚦 Loading model and scaler for site 4821...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Accuracy: 98.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 77.55434
